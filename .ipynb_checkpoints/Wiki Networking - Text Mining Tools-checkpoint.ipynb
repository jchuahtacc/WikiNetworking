# %% [markdown]
# # Wiki Networking - Text Mining Tools
#
# ### Introduction
#
# This notebook contains text mining and web crawling functions for working with Wikipedia articles. The first cell contains imports and settings for crawling Wikipedia.

# %%
from pyquery import PyQuery
import time


print "OK"
# Out:
# OK

# %% [markdown]
# ### `filter_links`
#
# This function accepts a PyQuery object and returns a list of Wikipedia article links from the article's main body text. It will not return links that are redirects or links that are anchors within other pages. Optionally, you can specify a DOM selector for the type of element containing links you wish to retrieve.

# %%
def filter_links(page, selector=""):
    result = []
    subchildren = PyQuery(page("#mw-content-text " + selector))
    for child in subchildren:
        links = PyQuery(child)("a")
        for link in links:
            linkQuery = PyQuery(link)
            if not linkQuery.hasClass("mw-redirect"):
                href = linkQuery.attr("href")
                if "/wiki/" in href and "#" not in href:
                    result.append(linkQuery.attr("href"))
    return result

# %% [markdown]
# In this example, we create a PyQuery object for the [Iron Man](https://en.wikipedia.org/wiki/Iron_Man) article on Wikipedia, retrieve its links with `filter_links` and output the number of links we retrieved.

# %%
iron_man_page = PyQuery(url="https://en.wikipedia.org/wiki/Iron_man")
iron_man_links = filter_links(iron_man_page)
print len(iron_man_links), "links retrieved"
# Out:
# 1205 links retrieved

# %% [markdown]
# In this example, we retrieve links from a [list of Hip Hop musicians](https://en.wikipedia.org/wiki/List_of_hip_hop_musicians). Notice that each link is contained inside of a `li` list item HTML tag.

# %%
hip_hop_page = PyQuery(url="https://en.wikipedia.org/wiki/List_of_hip_hop_musicians")
hip_hop_links = filter_links(hip_hop_page, "li")
print len(hip_hop_links), "links retrieved"
# Out:
# 1114 links retrieved

# %% [markdown]
# In this example, we do the same thing for [Harry Potter Characters](https://en.wikipedia.org/wiki/List_of_Harry_Potter_characters). Notice that many links are omitted - these links are redirects or links to sections within larger articles.

# %%
harry_potter_page = PyQuery(url="https://en.wikipedia.org/wiki/List_of_Harry_Potter_characters")
harry_potter_links = filter_links(harry_potter_page, "li")
print len(harry_potter_links), "links retrieved"
# Out:
# 144 links retrieved

# %% [markdown]
# In this example, we are retrieving a list of [Marvel Comics Characters beginning with the letter D](https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_D). In this case, we specify the DOM selector `.hatnote`. This is because we only want links for Marvel characters that have a dedicated _*Main article*_. The _*Main article*_ elements all have the `.hatnote` CSS class, so it is an easy way of selecting these articles. In this example, we simply print the contents of the list.

# %%
marvel_d_page = PyQuery(url="https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_D")
marvel_d_links = filter_links(marvel_d_page, ".hatnote")
print marvel_d_links
# Out:
# ['/wiki/Daken', '/wiki/Dakimh_the_Enchanter', '/wiki/Randall_Darby', '/wiki/Daredevil_(Marvel_Comics_character)', '/wiki/Dark_Beast', '/wiki/Dark_Mother', '/wiki/Darkdevil', '/wiki/Darkhawk', '/wiki/Darkoth', '/wiki/Darkstar_(comics)', '/wiki/Darwin_(comics)', '/wiki/Amanda_Sefton', '/wiki/Dazzler', '/wiki/Deacon_(comics)', '/wiki/Deadpool', '/wiki/Death_(Marvel_Comics)', '/wiki/Death_Adder_(comics)', '/wiki/Death_Metal_(comics)', '/wiki/Death-Stalker', '/wiki/Death%27s_Head', '/wiki/Deathbird', '/wiki/Deathlok', '/wiki/Death_Locket', '/wiki/Deathurge', '/wiki/Deathwatch_(comics)', '/wiki/Debrii', '/wiki/Valentina_Allegra_de_Fontaine', '/wiki/Marco_Delgado_(comics)', '/wiki/Marvel_Comics', '/wiki/DC_Comics', '/wiki/Demogoblin', '/wiki/Demolition_Man_(comics)', '/wiki/Demon_Bear', '/wiki/Desak', '/wiki/Destiny_(Irene_Adler)', '/wiki/Destiny_(Marvel_Comics_personification)', '/wiki/Destroyer_(Thor)', '/wiki/Devastator_(comics)', '/wiki/Devil_Dinosaur', '/wiki/Devos_the_Devastator', '/wiki/Jean_DeWolff', '/wiki/Rhomann_Dey', '/wiki/Diablo_(Marvel_Comics)', '/wiki/Diamond_Lil_(comics)', '/wiki/Diamondback_(comics)', '/wiki/Diamondhead_(comics)', '/wiki/Die-Cut_(comics)', '/wiki/Digger_(comics)', '/wiki/Digitek_(comics)', '/wiki/Dinah_Soar', '/wiki/Dionysus_(Marvel_Comics)', '/wiki/Dire_Wraith', '/wiki/Dirtnap_(comics)', '/wiki/Discus_(comics)', '/wiki/D%27Ken', '/wiki/Doc_Samson', '/wiki/Doctor_Bong', '/wiki/Doctor_Demonicus', '/wiki/Doctor_Doom', '/wiki/Doctor_Druid', '/wiki/Doctor_Faustus_(comics)', '/wiki/Doctor_Minerva', '/wiki/Doctor_Nemesis', '/wiki/Doctor_Spectrum', '/wiki/Doctor_Strange', '/wiki/Doctor_Sun', '/wiki/Daniel_Drumm', '/wiki/Stacy_Dolan', '/wiki/Neo_(Marvel_Comics_species)', '/wiki/Domino_(comics)', '/wiki/Big_Ben_Donovan', '/wiki/Roger_Dooley', '/wiki/Doom_2099', '/wiki/Doorman_(comics)', '/wiki/Doop_(comics)', '/wiki/Doppelganger_(comics)', '/wiki/Lemuel_Dorcas', '/wiki/Dorma_(comics)', '/wiki/Dormammu', '/wiki/Doughboy_(comics)', '/wiki/Dracula_(Marvel_Comics)', '/wiki/Dragon_Lord_(comics)', '/wiki/Dragon_Man', '/wiki/Dragonfly_(Marvel_Comics)', '/wiki/Dragoness_(comics)', '/wiki/Frank_Drake_(comics)', '/wiki/Drax_the_Destroyer', '/wiki/Dreadknight', '/wiki/Dreadnought_(comics)', '/wiki/Druig', '/wiki/Dryad_(comics)', '/wiki/D%27Spayre', '/wiki/Dummy_(DC_Comics)', '/wiki/List_of_Brotherhood_of_Mutants_members', '/wiki/Dusk_(comics)', '/wiki/Dust_(comics)', '/wiki/Dweller-in-Darkness']

# %% [markdown]
# ### `retrieve_multipage`
#
# This function retrieves data from a list of URLs. This is useful for when data on a Wikipedia category is broken up into multiple individual pages.

# %%
def retrieve_multipage(urls, selector="", verbose=False):
    import time  
    result = []
    for url in urls:
        time.sleep(1)
        if verbose:
            print "Retrieving " + url
        result.extend(filter_links(PyQuery(url=url), selector))
    return result

# %% [markdown]
# In this example, we are retrieving lists from all subpages from the [List of Marvel Comics Characters](https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters). The URL pattern for these articles is `https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_` followed by a section name.

# %%
sections = [letter for letter in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ']
sections.append('0-9')
urls = ["https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_" + section for section in sections]
print "URLs:", urls

character_links = retrieve_multipage(urls, ".hatnote", True)
print len(character_links), "links retrieved"
# Out:
# URLs: ['https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_A', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_B', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_C', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_D', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_E', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_F', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_G', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_H', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_I', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_J', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_K', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_L', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_M', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_N', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_O', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_P', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Q', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_R', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_S', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_T', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_U', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_V', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_W', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_X', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Y', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Z', 'https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_0-9']
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_A
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_B
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_C
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_D
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_E
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_F
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_G
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_H
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_I
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_J
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_K
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_L
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_M
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_N
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_O
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_P
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Q
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_R
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_S
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_T
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_U
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_V
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_W
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_X
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Y
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Z
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_0-9
# 2039 links retrieved

# %% [markdown]
# ### `write_list` and `read_list`
#
# These are convenience functions for writing and reading list data.

# %%
def write_list(data, filename):
    with open(filename, "w") as file:
        for item in data:
            file.write(item)
            file.write("\n")
            
def read_list(filename):
    with open(filename, "r") as file:
        return [item.strip() for item in file.readlines()]

# %% [markdown]
# In this example, we write all of the Marvel character links we retrieved to a text file, and verify that we can read the data from the file.

# %%
write_list(character_links, "all_marvel_chars.txt")
print len(read_list("all_marvel_chars.txt")), "read"
# Out:
# 2039 read

# %% [markdown]
# ### `intersection`
#
# Returns a list of elements that appear in both provided lists

# %%
def intersection(list1, list2):
    return [element for element in set(list1).intersection(list2)]

# %% [markdown]
# The `intersection` function is useful for cross referencing links from one Wikipedia page with another. For example, the [List of Hip Hop Musicians](https://en.wikipedia.org/wiki/List_of_hip_hop_musicians) contains many musicians, but we may not have the time or resources to crawl every single artist. The [BET Hip Hop Awards page](https://en.wikipedia.org/wiki/BET_Hip_Hop_Awards) has links to artists that have won an award and may be significant for our search, but it also contains links to songs and other media that may not be articles about individual Hip Hop artists. By taking the `intersection` of both, we get a list containing links of only Hip Hop arists that have won a BET Hip Hop Award.

# %%
hip_hop_page = PyQuery(url="https://en.wikipedia.org/wiki/List_of_hip_hop_musicians")
hip_hop_links = filter_links(hip_hop_page, "li")
print len(hip_hop_links), "links retrieved from List of Hip Hop Musicians"

bet_hip_hop_awards_page = PyQuery(url="https://en.wikipedia.org/wiki/BET_Hip_Hop_Awards")
bet_hip_hop_awards_links = filter_links(bet_hip_hop_awards_page, "li")
print len(bet_hip_hop_awards_links), "links retrieved from BET Hip Hop Awards"

award_winner_links = intersection(hip_hop_links, bet_hip_hop_awards_links)

print "BET Hip Hop Award winners:", award_winner_links
# Out:
# 1114 links retrieved from List of Hip Hop Musicians
# 705 links retrieved from BET Hip Hop Awards
# BET Hip Hop Award winners: ['/wiki/Jadakiss', '/wiki/Problem_(rapper)', '/wiki/Rapsody', '/wiki/B.o.B', '/wiki/Juicy_J', '/wiki/Schoolboy_Q', '/wiki/Gucci_Mane', '/wiki/Tech_N9ne', '/wiki/Jim_Jones_(rapper)', '/wiki/Black_Thought', '/wiki/Joe_Budden', '/wiki/Lil_Yachty', '/wiki/Unk', '/wiki/Keith_Murray_(rapper)', '/wiki/Angel_Haze', '/wiki/50_Cent', '/wiki/B.G._(rapper)', '/wiki/Stat_Quo', '/wiki/Jay_Electronica', '/wiki/Mystikal', '/wiki/
wiki/Nas', '/wiki/Ace_Hood', '/wiki/Shock_G', '/wiki/Young_Jeezy', '/wiki/Big_K.R.I.T.', '/wiki/Roscoe_Dash', '/wiki/XV_(rapper)', '/wiki/Yelawolf', '/wiki/Vado_(rapper)', '/wiki/Nipsey_Hussle', '/wiki/David_Banner', '/wiki/Nick_Cannon', '/wiki/Meek_Mill', '/wiki/Foxx_(rapper)', '/wiki/Drumma_Boy', '/wiki/Dorrough', '/wiki/Future_(rapper)', '/wiki/Joey_Badass', '/wiki/Cassidy_(rapper)', '/wiki/Plies_(rapper)', '/wiki/Saigon_(rapper)', '/wiki/Willy_Northpole', '/wiki/Lecrae', '/wiki/Bun_B', '/wiki/Mickey_Factz', '/wiki/Rocko_(rapper)', '/wiki/Big_Boi', '/wiki/Timbaland', '/wiki/Jay_Rock', '/wiki/DMX_(rapper)', '/wiki/Freeway_(rapper)', '/wiki/Hurricane_Chris_(rapper)', '/wiki/Dr._Dre', '/wiki/T.I.', '/wiki/Stalley', '/wiki/Queen_Latifah', '/wiki/Diamond_(rapper)', '/wiki/Wyclef_Jean', '/wiki/E-40', '/wiki/French_Montana', '/wiki/Lil_Mama', '/wiki/Fat_Joe', '/wiki/DJ_Khaled', '/wiki/Xzibit', '/wiki/Reema_Major', '/wiki/Busta_Rhymes', '/wiki/Lil_Wayne', '/wiki/YG_(rapper)', '/wiki/Snoop_Dogg', '/wiki/Mannie_Fresh', '/wiki/Wale_(rapper)', '/wiki/Casey_Veggies', '/wiki/Bow_Wow_(rapper)', '/wiki/Money-B', '/wiki/Wax_(rapper)', '/wiki/Termanology', '/wiki/Lil_Jon', '/wiki/Rakim', '/wiki/Kurupt', '/wiki/Lil_Scrappy', '/wiki/MC_Hammer', '/wiki/Los_(rapper)', '/wiki/Chance_the_Rapper', '/wiki/Scarface_(rapper)', '/wiki/The-Dream', '/wiki/B ...

# %% [markdown]
# ### `crawl`
#
# This crawls articles iteratively, with a two second delay between each page retrieval. It requires a starting URL fragment and an `accept` list of URLs the crawler should follow. It returns a dictionary structure with each URL fragment as a key and crawl data (`links`, `title` and `depth`) as a value.

# %%
def crawl(start, max_articles=200, max_depth=3, accept=list(), reject=list(), host="https://en.wikipedia.org"):
    from collections import deque
    result = dict()
    crawl_queue = deque()
    crawl_queue.append(start)
    count = 0
    while count < max_articles and len(crawl_queue) > 0:
        count = count + 1
        current = crawl_queue.popleft()
        print "{}: Retrieving {}, ({} left in queue)".format(count, current, len(crawl_queue))
        page = PyQuery(url=host+current)
        
        # Make sure page exists in structure
        if current not in result:
            result[current] = dict()
            result[current]["depth"] = 0
        
        # Save page data
        result[current]["title"] = page("#firstHeading").text()
        result[current]["links"] = [link for link in filter_links(page) if link in accept and link not in reject]
        
        # Check current depth, don't want to go to deep!
        if result[current]["depth"] <= max_depth: 
            for link in result[current]["links"]:
                if link not in result and link not in crawl_queue:
                    crawl_queue.append(link)
                    result[link] = dict()
                    result[link]["depth"] = result[current]["depth"] + 1
                    
        # Important!!!
        time.sleep(2)

    return result

# %% [markdown]
# In this example, we start a crawl at the article for [Jadakiss](https://en.wikipedia.org/wiki/Jadakiss). As the `accept` list of URLs that the crawler is allowed to follow, we will use the `award_winner_links` list from earlier. This isolates the crawl to only [Artist winners of BET Hip Hop Awards](https://en.wikipedia.org/wiki/BET_Hip_Hop_Awards). Therefore, our social network will be a network built of BET Hip Hop Award Winners and stored in the `bet_winner_crawl` dictionary.

# %%
bet_winner_crawl = crawl("/wiki/Jadakiss", accept=award_winner_links)
# Out:
# 1: Retrieving /wiki/Jadakiss, (0 left in queue)
# 2: Retrieving /wiki/DMX_(rapper), (28 left in queue)
# 3: Retrieving /wiki/Pharrell_Williams, (30 left in queue)
# 4: Retrieving /wiki/Swizz_Beatz, (38 left in queue)
# 5: Retrieving /wiki/Yo_Gotti, (40 left in queue)
# 6: Retrieving /wiki/Rick_Ross, (42 left in queue)
# 7: Retrieving /wiki/Fat_Joe, (49 left in queue)
# 8: Retrieving /wiki/DJ_Khaled, (55 left in queue)
# 9: Retrieving /wiki/Nicki_Minaj, (65 left in queue)
# 10: Retrieving /wiki/Styles_P, (65 left in queue)
# 11: Retrieving /wiki/Sean_Combs, (64 left in queue)
# 12: Retrieving /wiki/Snoop_Dogg, (63 left in queue)
# 13: Retrieving /wiki/Eminem, (69 left in queue)
# 14: Retrieving /wiki/Common_(rapper), (80 left in queue)
# 15: Retrieving /wiki/Nas, (83 left in queue)
# 16: Retrieving /wiki/Beanie_Sigel, (84 left in queue)
# 17: Retrieving /wiki/Freeway_(rapper), (84 left in queue)
# 18: Retrieving /wiki/Fabolous, (83 left in queue)
# 19: Retrieving /wiki/Ludacris, (83 left in queue)
# 20: Retrieving /wiki/Busta_Rhymes, (85 left in queue)
# 21: Retrieving /wiki/Twista, (86 left in queue)
# 22: Retrieving /wiki/Ace_Hood, (85 left in queue)
# 23: Retrieving /wiki/Bun_B, (87 left in queue)
# 24: Retrieving /wiki/Waka_Flocka_Flame, (88 left in queue)
# 25: Retrieving /wiki/The-Dream, (90 left in queue)
# 26: Retrieving /wiki/Young_Jeezy, (89 left in queue)
# 27: Retrieving /wiki/Wiz_Khalifa, (90 left in queue)
# 28: Retrieving /wiki/Lil_Wayne, (93 left in queue)
# 29: Retrieving /wiki/Future_(rapper), (95 left in queue)
# 30: Retrieving /wiki/50_Cent, (95 left in queue)
# 31: Retrieving /wiki/LL_Cool_J, (95 left in queue)
# 32: Retrieving /wiki/Kanye_West, (94 left in queue)
# 33: Retrieving /wiki/Dr._Dre, (98 left in queue)
# 34: Retrieving /wiki/Pusha_T, (99 left in queue)
# 35: Retrieving /wiki/T.I., (98 left in queue)
# 36: Retrieving /wiki/Nelly, (101 left in queue)
# 37: Retrieving /wiki/Mac_Miller, (100 left in queue)
# 38: Retrieving /wiki/Mike_Will_Made_It, (103 left in queue)
# 39: Retrieving /wiki/Rakim, (104 left in queue)
# 40: Retrieving /wiki/Lupe_Fiasco, (103 left in queue)
# 41: Retrieving /wiki/Lil_Jon, (103 left in queue)
# 42: Retrieving /wiki/T-Pain, (103 left in queue)
# 43: Retrieving /wiki/Cassidy_(rapper), (103 left in queue)
# 44: Retrieving /wiki/Plies_(rapper), (102 left in queue)
# 45: Retrieving /wiki/2_Chainz, (101 left in queue)
# 46: Retrieving /wiki/Gucci_Mane, (101 left in queue)
# 47: Retrieving /wiki/YG_(rapper), (101 left in queue)
# 48: Retrieving /wiki/J._Cole, (101 left in queue)
# 49: Retrieving /wiki/Meek_Mill, (100 left in queue)
# 50: Retrieving /wiki/Wale_(rapper), (99 left in queue)
# 51: Retrieving /wiki/French_Montana, (100 left in queue)
# 52: Retrieving /wiki/Erick_Sermon, (101 left in queue)
# 53: Retrieving /wiki/Stalley, (100 left in queue)
# 54: Retrieving /wiki/Birdman_(rapper), (100 left in queue)
# 55: Retrieving /wiki/The_Game_(rapper), (99 left in queue)
# 56: Retrieving /wiki/Rocko_(rapper), (99 left in queue)
# 57: Retrieving /wiki/KRS-One, (98 left in queue)
# 58: Retrieving /wiki/Raekwon, (98 left in queue)
# 59: Retrieving /wiki/Remy_Ma, (97 left in queue)
# 60: Retrieving /wiki/Keith_Murray_(rapper), (96 left in queue)
# 61: Retrieving /wiki/Akon, (95 left in queue)
# 62: Retrieving /wiki/Big_Boi, (94 left in queue)
# 63: Retrieving /wiki/Lil%27_Kim, (94 left in queue)
# 64: Retrieving /wiki/Luther_Campbell, (95 left in queue)
# 65: Retrieving /wiki/Bow_Wow_(rapper), (94 left in queue)
# 66: Retrieving /wiki/Big_Sean, (93 left in queue)
# 67: Retrieving /wiki/Kirko_Bangz, (93 left in queue)
# 68: Retrieving /wiki/Tyga, (93 left in queue)
# 69: Retrieving /wiki/Kendrick_Lamar, (92 left in queue)
# 70: Retrieving /wiki/Big_K.R.I.T., (93 left in queue)
# 71: Retrieving /wiki/Scarface_(rapper), (93 left in queue)
# 72: Retrieving /wiki/Chance_the_Rapper, (92 left in queue)
# 73: Retrieving /wiki/Jim_Jones_(rapper), (94 left in queue)
# 74: Retrieving /wiki/Vado_(rapper), (94 left in queue)
# 75: Retrieving /wiki/Ice_Cube, (93 left in queue)
# 76: Retrieving /wiki/Kurupt, (92 left in queue)
# 77: Retrieving /wiki/Xzibit, (91 left in queue)
# 78: Retrieving /wiki/David_Banner, (90 left in queue)
# 79: Retrieving /wiki/E-40, (89 left in queue)
# 80: Retrieving /wiki/Tech_N9ne, (89 left in queue)
# 81: Retrieving /wiki/DJ_Drama, (90 left in queue)
# 82: Retrieving /wiki/The_Lady_of_Rage, (89 left in queue)
# 83: Retrieving /wiki/Royce_da_5%279%22, (88 left in queue)
# 84: Retrieving /wiki/MC_Hammer, (87 left in queue)
# 85: Retrieving /wiki/B.o.B, (88 left in queue)
# 86: Retrieving /wiki/Yelawolf, (89 left in queue)
# 87: Retrieving /wiki/Stat_Quo, (88 left in queue)
# 88: Retrieving /wiki/Redman_(rapper), (87 left in queue)
# 89: Retrieving /wiki/Crooked_I, (86 left in queue)
# 90: Retrieving /wiki/Ab-Soul, (85 left in queue)
# 91: Retrieving /wiki/Hopsin, (84 left in queue)
# 92: Retrieving /wiki/Joe_Budden, (83 left in queue)
# 93: Retrieving /wiki/Talib_Kweli, (82 left in queue)
# 94: Retrieving /wiki/Juicy_J, (82 left in queue)
# 95: Retrieving /wiki/Mos_Def, (81 left in queue)
# 96: Retrieving /wiki/Black_Thought, (80 left in queue)
# 97: Retrieving /wiki/Vince_Staples, (81 left in queue)
# 98: Retrieving /wiki/Queen_Latifah, (80 left in queue)
# 99: Retrieving /wiki/Timbaland, (79 left in queue)
# 100: Retrieving /wiki/Dave_East, (80 left in queue)
# 101: Retrieving /wiki/Omillio_Sparks, (79 left in queue)
# 102: Retrieving /wiki/Jermaine_Dupri, (78 left in queue)
# 103: Retrieving /wiki/Mystikal, (77 left in queue)
# 104: Retrieving /wiki/DJ_Quik, (76 left in queue)
# 105: Retrieving /wiki/Willy_Northpole, (75 left in queue)
# 106: Retrieving /wiki/Joell_Ortiz, (74 left in queue)
# 107: Retrieving /wiki/Papoose_(rapper), (73 left in queue)
# 108: Retrieving /wiki/Rich_Homie_Quan, (72 left in queue)
# 109: Retrieving /wiki/Juelz_Santana, (71 left in queue)
# 110: Retrieving /wiki/Kevin_McCall, (70 left in queue)
# 111: Retrieving /wiki/Webbie, (69 left in queue)
# 112: Retrieving /wiki/Yung_Joc, (69 left in queue)
# 113: Retrieving /wiki/Wyclef_Jean, (68 left in queue)
# 114: Retrieving /wiki/Juvenile_(rapper), (67 left in queue)
# 115: Retrieving /wiki/Roscoe_Dash, (66 left in queue)
# 116: Retrieving /wiki/Mannie_Fresh, (65 left in queue)
# 117: Retrieving /wiki/DJ_Mustard, (64 left in queue)
# 118: Retrieving /wiki/Chevy_Woods, (64 left in queue)
# 119: Retrieving /wiki/Lil_Uzi_Vert, (63 left in queue)
# 120: Retrieving /wiki/Pill_(rapper), (62 left in queue)
# 121: Retrieving /wiki/Diggy_Simmons, (61 left in queue)
# 122: Retrieving /wiki/B.G._(rapper), (60 left in queue)
# 123: Retrieving /wiki/Jay_Rock, (59 left in queue)
# 124: Retrieving /wiki/Omarion, (58 left in queue)
# 125: Retrieving /wiki/Metro_Boomin, (57 left in queue)
# 126: Retrieving /wiki/Lil_Scrappy, (56 left in queue)
# 127: Retrieving /wiki/Desiigner, (55 left in queue)
# 128: Retrieving /wiki/Rhymefest, (54 left in queue)
# 129: Retrieving /wiki/Vic_Mensa, (53 left in queue)
# 130: Retrieving /wiki/Soulja_Boy, (52 left in queue)
# 131: Retrieving /wiki/Casey_Veggies, (51 left in queue)
# 132: Retrieving /wiki/Grandmaster_Flash, (50 left in queue)
# 133: Retrieving /wiki/Kardinal_Offishall, (49 left in queue)
# 134: Retrieving /wiki/Iggy_Azalea, (48 left in queue)
# 135: Retrieving /wiki/Young_Dro, (47 left in queue)
# 136: Retrieving /wiki/Young_Thug, (46 left in queue)
# 137: Retrieving /wiki/Shawty_Lo, (45 left in queue)
# 138: Retrieving /wiki/Rapsody, (44 left in queue)
# 139: Retrieving /wiki/Schoolboy_Q, (43 left in queue)
# 140: Retrieving /wiki/Action_Bronson, (42 left in queue)
# 141: Retrieving /wiki/Jay_Electronica, (42 left in queue)
# 142: Retrieving /wiki/Lil_Yachty, (41 left in queue)
# 143: Retrieving /wiki/21_Savage, (40 left in queue)
# 144: Retrieving /wiki/Charles_Hamilton_(rapper), (39 left in queue)
# 145: Retrieving /wiki/Krayzie_Bone, (38 left in queue)
# 146: Retrieving /wiki/Lil_Mama, (37 left in queue)
# 147: Retrieving /wiki/Drumma_Boy, (37 left in queue)
# 148: Retrieving /wiki/Fetty_Wap, (36 left in queue)
# 149: Retrieving /wiki/Nipsey_Hussle, (35 left in queue)
# 150: Retrieving /wiki/Saigon_(rapper), (34 left in queue)
# 151: Retrieving /wiki/K%27naan, (33 left in queue)
# 152: Retrieving /wiki/Kid_Ink, (32 left in queue)
# 153: Retrieving /wiki/Kevin_Gates, (31 left in queue)
# 154: Retrieving /wiki/Ras_Kass, (30 left in queue)
# 155: Retrieving /wiki/Problem_(rapper), (29 left in queue)
# 156: Retrieving /wiki/Buckshot_(rapper), (28 left in queue)
# 157: Retrieving /wiki/Nick_Cannon, (27 left in queue)
# 158: Retrieving /wiki/MC_Lyte, (26 left in queue)
# 159: Retrieving /wiki/Tiffany_Foxx, (25 left in queue)
# 160: Retrieving /wiki/Dom_Kennedy, (24 left in queue)
# 161: Retrieving /wiki/Chamillionaire, (23 left in queue)
# 162: Retrieving /wiki/Isaiah_Rashad, (22 left in queue)
# 163: Retrieving /wiki/Mickey_Factz, (21 left in queue)
# 164: Retrieving /wiki/Lecrae, (20 left in queue)
# 165: Retrieving /wiki/Troy_Ave, (20 left in queue)
# 166: Retrieving /wiki/Jon_Connor, (19 left in queue)
# 167: Retrieving /wiki/Jarren_Benton, (18 left in queue)
# 168: Retrieving /wiki/Dej_Loaf, (18 left in queue)
# 169: Retrieving /wiki/G-Eazy, (17 left in queue)
# 170: Retrieving /wiki/Snow_Tha_Product, (16 left in queue)
# 171: Retrieving /wiki/Rittz, (15 left in queue)
# 172: Retrieving /wiki/Doug_E._Fresh, (15 left in queue)
# 173: Retrieving /wiki/Shock_G, (14 left in queue)
# 174: Retrieving /wiki/Rich_Boy, (14 left in queue)
# 175: Retrieving /wiki/Cory_Gunz, (13 left in queue)
# 176: Retrieving /wiki/Jean_Grae, (12 left in queue)
# 177: Retrieving /wiki/Rahzel, (11 left in queue)
# 178: Retrieving /wiki/Joey_Badass, (10 left in queue)
# 179: Retrieving /wiki/Tink_(musician), (9 left in queue)
# 180: Retrieving /wiki/Ms._Jade, (8 left in queue)
# 181: Retrieving /wiki/Foxx_(rapper), (7 left in queue)
# 182: Retrieving /wiki/Dorrough, (6 left in queue)
# 183: Retrieving /wiki/Termanology, (5 left in queue)
# 184: Retrieving /wiki/Angel_Haze, (4 left in queue)
# 185: Retrieving /wiki/Andy_Mineo, (3 left in queue)
# 186: Retrieving /wiki/Locksmith_(rapper), (2 left in queue)
# 187: Retrieving /wiki/Wax_(rapper), (1 left in queue)
# 188: Retrieving /wiki/Money-B, (0 left in queue)

# %%
print bet_winner_crawl
# Out:
_J', '/wiki/Mac_Miller', '/wiki/Iggy_Azalea', '/wiki/Big_Boi', '/wiki/Wiz_Khalifa', '/wiki/2_Chainz', '/wiki/Future_(rapper)', '/wiki/Kevin_Gates', '/wiki/Tech_N9ne', '/wiki/2_Chainz', '/wiki/Eminem', '/wiki/DMX_(rapper)', '/wiki/Dr._Dre', '/wiki/Eminem', '/wiki/T.I.', '/wiki/T.I.'], 'title': 'B.o.B'}, '/wiki/Juicy_J': {'depth': 2, 'links': ['/wiki/Lil_Wayne', '/wiki/Wiz_Khalifa', '/wiki/2_Chainz', '/wiki/French_Montana', '/wiki/Wiz_Khalifa', '/wiki/Wiz_Khalifa', '/wiki/2_Chainz', '/wiki/Lil_Wayne', '/wiki/Mike_Will_Made_It', '/wiki/Nas', '/wiki/Dr._Dre', '/wiki/Wiz_Khalifa', '/wiki/Nicki_Minaj', '/wiki/Young_Jeezy', '/wiki/Yelawolf', '/wiki/Big_Sean', '/wiki/Big_Sean', '/wiki/Young_Jeezy', '/wiki/Nicki_Minaj', '/wiki/Young_Thug', '/wiki/Wiz_Khalifa', '/wiki/B.o.B', '/wiki/T.I.', '/wiki/Mike_Will_Made_It', '/wiki/Wiz_Khalifa', '/wiki/Wiz_Khalifa', '/wiki/Wiz_Khalifa', '/wiki/Eminem', '/wiki/Eminem', '/wiki/Common_(rapper)'], 'title': 'Juicy J'}, '/wiki/Schoolboy_Q': {'depth': 3, 'links': ['/wiki/50_Cent', '/wiki/Mac_Miller', '/wiki/Tyga', '/wiki/Ab-Soul', '/wiki/Jay_Rock', '/wiki/Kendrick_Lamar', '/wiki/Jay_Rock', '/wiki/Ab-Soul', '/wiki/Tyga', '/wiki/Kendrick_Lamar', '/wiki/Tyga', '/wiki/Wiz_Khalifa', '/wiki/Mac_Miller', '/wiki/Kendrick_Lamar', '/wiki/Kendrick_Lamar', '/wiki/Snoop_Dogg', '/wiki/Mac_Miller', '/wiki/Isaiah_Rashad', '/wiki/Isaiah_Rashad', '/wiki/Vince_Staples', '/wiki/Kanye_West', '/wiki/Nas', '/wiki/50_Cent', '/wiki/Kurupt', '/wiki/Sean_Combs', '/wiki/Kanye_West', '/wiki/Ab-Soul', '/wiki/Jay_Rock', '/wiki/Kendrick_Lamar', '/wiki/Ab-Soul', '/wiki/Isaiah_Rashad', '/wiki/Jay_Rock', '/wiki/Kendrick_Lamar'], 'title': 'Schoolboy Q'}, '/wiki/Redman_(rapper)': {'depth': 2, 'links': ['/wi ...

# %% [markdown]
# ### `directed_graph` and `undirected_graph`
#
# These functions flatten the raw crawl data into something a little more usable. It returns a dictionary with only article title names as the key, and corresponding urls and a dictionary of edges and weights to each article. The `directed_graph` function allows each article to retain a separate edge representing back links, while the `undirected_graph` creates one edge from each pair of article where the weight is a sum of the links between each article. For example, `directed_graph` might produce:
#
# ```
# {
#    'Iron Man' : {
#        'url' : '/wiki/Iron_Man',
#        'edges' : {
#            'Captain America' : 11
#        }
#    },
#    'Captain America' : {
#        'url' : '/wiki/Captain_America',
#        'edges' : {
#            'Iron Man' : 8
#        }
#    }
# }
# ```
#
# ...while the same data passed to `undirected_graph` might produce:
#
#
# ```
# {
#     'Iron Man' : {
#         'url' : '/wiki/Iron_Man',
#         'edges' : {
#             'Captain America' : 19
#         }
#     },
#     'Captain America' : {
#         'url' : /wiki/Captain_America',
#         'edges' : {
#         }
#     }
# }
# ```

# %%
def directed_graph(data):
    result = dict()
    for item in data:
        current_title = data[item]["title"]
        result[current_title] = dict()
        result[current_title]["url"] = item
        result[current_title]["edges"] = dict()
        for link in data[item]["links"]:
            link_title = data[link]["title"]
            if link_title not in result[current_title]:
                result[current_title]["edges"][link_title] = data[item]["links"].count(link)
    return result

# %%
directed_graph_dict = directed_graph(bet_winner_crawl)
print directed_graph_dict
# Out:
# {'Mannie Fresh': {'url': '/wiki/Mannie_Fresh', 'edges': {'Lil Wayne': 2, 'B.G. (rapper)': 1, 'Mos Def': 1, 'Juvenile (rapper)': 1, 'Rick Ross': 1, 'Birdman (rapper)': 3, 'Lil Jon': 1, 'T.I.': 1, 'Mystikal': 1}}, 'Beanie Sigel': {'url': '/wiki/Beanie_Sigel', 'edges': {'Kanye West': 1, 'Jadakiss': 3, 'DMX (rapper)': 1, '50 Cent': 2, 'Raekwon': 1, 'Freeway (rapper)': 4, 'Omillio Sparks': 2, 'Meek Mill': 1, 'Scarface (rapper)': 2}}, 'Nipsey Hussle': {'url': '/wiki/Nipsey_Hussle', 'edges': {'Problem (rapper)': 1, 'Dom Kennedy': 3, 'DJ Drama': 1, 'Jay Rock': 1, 'YG (rapper)': 3, 'Rick Ross': 3, 'Freeway (rapper)': 1, 'Big Sean': 1, 'Dr. Dre': 1, 'DJ Mustard': 1, 'Tyga': 1, 'Snoop Dogg': 2}}, 'Nicki Minaj': {'url': '/wiki/Nicki_Minaj', 'edges': {'Lil Wayne': 6, 'Kanye West': 3, 'Busta Rhymes': 1, 'Remy Ma': 3, 'Ludacris': 1, 'Jadakiss': 1, 'Eminem': 2, 'Birdman (rapper)': 1, 'Yo Gotti': 2, 'Meek Mill': 2, 'Big Sean': 1, 'Ice Cube': 1, 'Tyga': 1, 'Gucci Mane': 1, "Lil' Kim": 3}}, 'Charles Hamilton (rapper)': {'url': '/wiki/Charles_Hamilton_(rapper)', 'edges': {'Ace Hood': 1, 'Cory Gunz': 1, 'Kanye West': 1, 'Dr. Dre': 2, 'B.o.B': 2, 'Wale (rapper)': 1, 'DMX (rapper)': 1, 'MC Lyte': 2, '50 Cent': 1, 'Eminem': 4, 'Nas': 1, 'The-Dream': 1, 'Mickey Factz': 2, 'Lupe Fiasco': 1}}, 'Jermaine Dupri': {'url': '/wiki/Jermaine_Dupri', 'edges': {'Lil Wayne': 1, 'Ludacris': 1, 'Queen Latifah': 1, 'Nelly': 1, 'Grandmaster Flash': 1, 'Bow Wow (rapper)': 4, "Lil' Kim": 1}}, 'Redman (rapper)': {'url': '/wiki/Redman_(rapper)', 'edges': {'Erick Sermon': 1, 'Eminem': 1}}, 'Grandmaster Flash': {'url': '/wiki/Grandmaster_Flash', 'edges': {}}, 'Erick Sermon': {'url': '/wiki/Erick_S
# %%
def undirected_graph(data):
    result = dict()
    for item in data:
        current_title = data[item]["title"]
        result[current_title] = dict()
        result[current_title]["url"] = item
        result[current_title]["edges"] = dict()
        already_counted = list()
        for link in data[item]["links"]:
            if link not in already_counted:
                link_title = data[link]["title"]
                if link_title in result and current_title in result[link_title]["edges"]:
                    result[link_title]["edges"][current_title] += data[item]["links"].count(link)
                elif link_title not in result[current_title]:
                    result[current_title]["edges"][link_title] = data[item]["links"].count(link)
                already_counted.append(link)
    return result

# %%
undirected_graph_dict = undirected_graph(bet_winner_crawl)
print undirected_graph_dict
# Out:
# Juicy J already exists in B.o.B
# Tech N9ne already exists in B.o.B
# 50 Cent already exists in Jadakiss
# Kanye West already exists in 50 Cent
# Snow Tha Product already exists in Tech N9ne
# Rich Homie Quan already exists in Birdman (rapper)
# Metro Boomin already exists in Gucci Mane
# Shawty Lo already exists in Gucci Mane
# Swizz Beatz already exists in Jadakiss
# Mac Miller already exists in Schoolboy Q
# Mac Miller already exists in Jay Electronica
# Lil Uzi Vert already exists in Metro Boomin
# Plies (rapper) already exists in Gucci Mane
# Big Sean already exists in Kanye West
# Big Sean already exists in Juicy J
# Rahzel already exists in Black Thought
# Vic Mensa already exists in Kanye West
# 21 Savage already exists in Metro Boomin
# The Game (rapper) already exists in 50 Cent
# The Game (rapper) already exists in Jim Jones (rapper)
# The Game (rapper) already exists in Stat Quo
# Charles Hamilton (rapper) already exists in B.o.B
# DJ Quik already exists in Problem (rapper)
# Pharrell Williams already exists in Kanye West
# Pharrell Williams already exists in Mac Miller
# Pharrell Williams already exists in 50 Cent
# J. Cole already exists in Jay Electronica
# J. Cole already exists in B.o.B
# J. Cole already exists in Big Sean
# 2 Chainz already exists in Kanye West
# 2 Chainz already exists in Gucci Mane
# 2 Chainz already exists in Rich Homie Quan
# 2 Chainz already exists in Big Sean
# Iggy Azalea already exists in B.o.B
# T-Pain already exists in Plies (rapper)
# T-Pain already exists in 50 Cent
# T-Pain already exists in Tech N9ne
# T-Pain already exists in Pharrell Williams
# Chevy Woods already exists in Dej Loaf
# Juelz Santana already exists in Jim Jones (rapper)
# Kevin Gates already exists in Chevy Woods
# Omarion already exists in Gucci Mane
# Omarion already exists in T-Pain
# Common (rapper) already exists in Kanye West
# Common (rapper) already exists in Black Thought
# Common (rapper) already exists in Juicy J
# Chance the Rapper already exists in Vic Mensa
# Chance the Rapper already exists in Kanye West
# Chance the Rapper already exists in J. Cole
# Chance the Rapper already exists in 2 Chainz
# Rittz already exists in Tech N9ne
# Yung Joc already exists in T-Pain
# Lil' Kim already exists in T-Pain
# Lil' Kim already exists in Shawty Lo
# Lil' Kim already exists in Tiffany Foxx
# Lil' Kim already exists in Iggy Azalea
# DJ Drama already exists in Gucci Mane
# DJ Mustard already exists in Iggy Azalea
# DJ Mustard already exists in T-Pain
# DJ Mustard already exists in Big Sean
# Isaiah Rashad already exists in Chance the Rapper
# Isaiah Rashad already exists in Schoolboy Q
# Styles P already exists in Swizz Beatz
# Styles P already exists in Jadakiss
# Joell Ortiz already exists in Snow Tha Product
# Joell Ortiz already exists in Joe Budden
# KRS-One already exists in K'naan
# KRS-One already exists in Buckshot (rapper)
# Nicki Minaj already exists in Gucci Mane
# Nicki Minaj already exists in Lil' Kim
# Nicki Minaj already exists in Kanye West
# Nicki Minaj already exists in Jadakiss
# Nicki Minaj already exists in Big Sean
# Nicki Minaj already exists in Birdman (rapper)
# Ice Cube already exists in DJ Quik
# Twista already exists in Kanye West
# Twista already exists in Tech N9ne
# Twista already exists in T-Pain
# Fetty Wap already exists in Gucci Mane
# Roscoe Dash already exists in Big Sean
# Roscoe Dash already exists in Iggy Azalea
# Juvenile (rapper) already exists in Birdman (rapper)
# Erick Sermon already exists in Keith Murray (rapper)
# Erick Sermon already exists in Redman (rapper)
# Crooked I already exists in Snow Tha Product
# Crooked I already exists in Joe Budden
# Crooked I already exists in Joell Ortiz
# Jarren Benton already exists in Tech N9ne
# Jarren Benton already exists in Locksmith (rapper)
# Kendrick Lamar already exists in J. Cole
# Kendrick Lamar already exists in Isaiah Rashad
# Kendrick Lamar already exists in The Game (rapper)
# Kendrick Lamar already exists in Schoolboy Q
# Kendrick Lamar already exists in Tech N9ne
# Kendrick Lamar already exists in 2 Chainz
# Kendrick Lamar already exists in Big Sean
# Kendrick Lamar already exists in Jay Electronica
# Kendrick Lamar already exists in Kanye West
# Kendrick Lamar already exists in Chance the Rapper
# Pusha T already exists in Kanye West
# Pusha T already exists in Pharrell Williams
# Pusha T already exists in Swizz Beatz
# Pusha T already exists in Big Sean
# Pusha T already exists in 2 Chainz
# Nelly already exists in Jermaine Dupri
# Nelly already exists in T-Pain
# MC Lyte already exists in Lil' Kim
# Rhymefest already exists in Kanye West
# Mos Def already exists in Kanye West
# Mos Def already exists in K'naan
# Mos Def already exists in Jay Electronica
# Mos Def already exists in Kendrick Lamar
# Mos Def already exists in Common (rapper)
# Sean Combs already exists in Lil' Kim
# Sean Combs already exists in 50 Cent
# Sean Combs already exists in Nelly
# Rick Ross already exists in Sean Combs
# Rick Ross already exists in T-Pain
# Rick Ross already exists in Nelly
# Rick Ross already exists in Birdman (rapper)
# Rick Ross already exists in 50 Cent
# B.G. (rapper) already exists in Juvenile (rapper)
# B.G. (rapper) already exists in Birdman (rapper)
# Casey Veggies already exists in Mac Miller
# Dom Kennedy already exists in Casey Veggies
# Dom Kennedy already exists in Big Sean
# Dom Kennedy already exists in DJ Mustard
# Ab-Soul already exists in Mac Miller
# Ab-Soul already exists in Kendrick Lamar
# Ab-Soul already exists in Schoolboy Q
# Ab-Soul already exists in Isaiah Rashad
# Rapsody already exists in Mac Miller
# Raekwon already exists in Black Thought
# Soulja Boy already exists in Kanye West
# Eminem already exists in 50 Cent
# Eminem already exists in Ice Cube
# Eminem already exists in B.o.B
# Eminem already exists in Big Sean
# Eminem already exists in Tech N9ne
# Eminem already exists in Stat Quo
# Eminem already exists in Jadakiss
# Eminem already exists in Redman (rapper)
# Eminem already exists in Nicki Minaj
# Vado (rapper) already exists in Dave East
# Nipsey Hussle already exists in Dom Kennedy
# Nipsey Hussle already exists in Problem (rapper)
# Nipsey Hussle already exists in DJ Mustard
# Nick Cannon already exists in Soulja Boy
# Nick Cannon already exists in Cory Gunz
# Foxx (rapper) already exists in Webbie
# Drumma Boy already exists in Gucci Mane
# Drumma Boy already exists in 2 Chainz
# Future (rapper) already exists in Metro Boomin
# Future (rapper) already exists in Young Jeezy
# Future (rapper) already exists in Gucci Mane
# Future (rapper) already exists in Mike Will Made It
# Future (rapper) already exists in Pusha T
# Future (rapper) already exists in Kanye West
# Future (rapper) already exists in Ace Hood
# Future (rapper) already exists in Rick Ross
# Future (rapper) already exists in Pharrell Williams
# Joey Badass already exists in Black Thought
# Joey Badass already exists in Troy Ave
# Cassidy (rapper) already exists in Swizz Beatz
# Wiz Khalifa already exists in Chevy Woods
# Wiz Khalifa already exists in DJ Mustard
# Wiz Khalifa already exists in Juicy J
# Wiz Khalifa already exists in Mac Miller
# Wiz Khalifa already exists in Lil Uzi Vert
# Wiz Khalifa already exists in The Game (rapper)
# Wiz Khalifa already exists in J. Cole
# Wiz Khalifa already exists in Eminem
# Wiz Khalifa already exists in Common (rapper)
# Saigon (rapper) already exists in Chamillionaire
# Willy Northpole already exists in Ludacris
# Lecrae already exists in Saigon (rapper)
# Lecrae already exists in Big K.R.I.T.
# Lecrae already exists in Andy Mineo
# Bun B already exists in Big K.R.I.T.
# Bun B already exists in Kirko Bangz
# Bun B already exists in Webbie
# Rocko (rapper) already exists in Gucci Mane
# Rocko (rapper) already exists in Drumma Boy
# Rocko (rapper) already exists in Future (rapper)
# Rocko (rapper) already exists in Rick Ross
# Big Boi already exists in B.o.B
# Big Boi already exists in Ludacris
# Big Boi already exists in Nick Cannon
# Timbaland already exists in Ludacris
# Timbaland already exists in Tink (musician)
# Timbaland already exists in Lil' Kim
# Timbaland already exists in 50 Cent
# Timbaland already exists in Pusha T
# Timbaland already exists in Nas
# Timbaland already exists in Omarion
# Jay Rock already exists in Tech N9ne
# Jay Rock already exists in Nipsey Hussle
# Jay Rock already exists in Kendrick Lamar
# Jay Rock already exists in Schoolboy Q
# Jay Rock already exists in Ab-Soul
# Jay Rock already exists in Isaiah Rashad
# DMX (rapper) already exists in Swizz Beatz
# DMX (rapper) already exists in Eminem
# DMX (rapper) already exists in 50 Cent
# Ms. Jade already exists in Timbaland
# Dr. Dre already exists in Eminem
# Dr. Dre already exists in Nas
# Dr. Dre already exists in 50 Cent
# Dr. Dre already exists in The Game (rapper)
# Dr. Dre already exists in Kendrick Lamar
# Dr. Dre already exists in DJ Quik
# Dr. Dre already exists in Ice Cube
# Dr. Dre already exists in The Lady of Rage
# Dr. Dre already exists in Raekwon
# Dr. Dre already exists in Timbaland
# Dr. Dre already exists in Stat Quo
# Dr. Dre already exists in Joell Ortiz
# T.I. already exists in B.o.B
# T.I. already exists in DJ Drama
# T.I. already exists in Iggy Azalea
# T.I. already exists in Nelly
# T.I. already exists in Pharrell Williams
# T.I. already exists in Young Dro
# T.I. already exists in Young Jeezy
# Kurupt already exists in Buckshot (rapper)
# Kurupt already exists in Ras Kass
# Kurupt already exists in Crooked I
# Kurupt already exists in Kendrick Lamar
# Kurupt already exists in Eminem
# Kurupt already exists in The Lady of Rage
# Lil Scrappy already exists in Yung Joc
# Lil Scrappy already exists in 50 Cent
# Lil Scrappy already exists in Lil Jon
# MC Hammer already exists in Doug E. Fresh
# MC Hammer already exists in Eminem
# MC Hammer already exists in Chamillionaire
# The-Dream already exists in Fabolous
# The-Dream already exists in Pusha T
# The-Dream already exists in Plies (rapper)
# The-Dream already exists in Snoop Dogg
# Beanie Sigel already exists in Raekwon
# Beanie Sigel already exists in Scarface (rapper)
# Beanie Sigel already exists in Kanye West
# Beanie Sigel already exists in Freeway (rapper)
# Beanie Sigel already exists in Omillio Sparks
# Beanie Sigel already exists in Jadakiss
# Papoose (rapper) already exists in Busta Rhymes
# Action Bronson already exists in Termanology
# Lupe Fiasco already exists in B.o.B
# Lupe Fiasco already exists in Kanye West
# Lupe Fiasco already exists in Pharrell Williams
# Lupe Fiasco already exists in Charles Hamilton (rapper)
# Lupe Fiasco already exists in Diggy Simmons
# Lupe Fiasco already exists in Wale (rapper)
# Lupe Fiasco already exists in Mos Def
# Lupe Fiasco already exists in Talib Kweli
# Meek Mill already exists in DJ Drama
# Meek Mill already exists in Nicki Minaj
# Meek Mill already exists in Rick Ross
# Meek Mill already exists in Wale (rapper)
# Meek Mill already exists in T.I.
# Meek Mill already exists in DJ Khaled
# Meek Mill already exists in Cassidy (rapper)
# Meek Mill already exists in The Game (rapper)
# Meek Mill already exists in Beanie Sigel
# Meek Mill already exists in Kendrick Lamar
# Meek Mill already exists in Big K.R.I.T.
# Meek Mill already exists in 50 Cent
# Meek Mill already exists in French Montana
# Krayzie Bone already exists in Chamillionaire
# Tyga already exists in 2 Chainz
# Tyga already exists in Birdman (rapper)
# Tyga already exists in Kid Ink
# Tyga already exists in The Game (rapper)
# Tyga already exists in Kevin McCall
# Tyga already exists in Nicki Minaj
# Tyga already exists in DJ Mustard
# LL Cool J already exists in DMX (rapper)
# LL Cool J already exists in 50 Cent
# LL Cool J already exists in Timbaland
# LL Cool J already exists in Queen Latifah
# E-40 already exists in Lil Jon
# E-40 already exists in Snoop Dogg
# E-40 already exists in Tech N9ne
# E-40 already exists in Young Jeezy
# Vince Staples already exists in Mac Miller
# Vince Staples already exists in Schoolboy Q
# Vince Staples already exists in Isaiah Rashad
# Waka Flocka Flame already exists in Gucci Mane
# Waka Flocka Flame already exists in French Montana
# Waka Flocka Flame already exists in Roscoe Dash
# Waka Flocka Flame already exists in Wale (rapper)
# Jean Grae already exists in Talib Kweli
# Jean Grae already exists in Rapsody
# Remy Ma already exists in Papoose (rapper)
# Remy Ma already exists in French Montana
# Remy Ma already exists in Fat Joe
# Remy Ma already exists in Queen Latifah
# Remy Ma already exists in Nicki Minaj
# Akon already exists in Lil Wayne
# Akon already exists in T-Pain
# Akon already exists in Young Jeezy
# Akon already exists in Kardinal Offishall
# Akon already exists in Eminem
# Akon already exists in Dr. Dre
# Akon already exists in Styles P
': 1, 'Action Bronson': 1, 'Eminem': 2, 'Mac Miller': 1, 'Jon Connor': 1, 'Kevin Gates': 1, 'Ab-Soul': 1, 'Common (rapper)': 1, 'Troy Ave': 1, 'Metro Boomin': 1, 'Isaiah Rashad': 2, 'Lil Uzi Vert': 1, 'Pharrell Williams': 1, 'Lupe Fiasco': 1, 'Twista': 1, 'Schoolboy Q': 1, 'The-Dream': 1}}, 'Scarface (rapper)': {'url': '/wiki/Scarface_(rapper)', 'edges': {'Beanie Sigel': 4, 'Ludacris': 1, 'Akon': 1, 'Nas': 1, 'Freeway (rapper)': 1, 'Ice Cube': 2, 'Tech N9ne': 1, 'Eminem': 1}}, 'Shock G': {'url': '/wiki/Shock_G', 'edges': {'E-40': 1, 'Dr. Dre': 1, 'Money-B': 4}}, 'Lil Mama': {'url': '/wiki/Lil_Mama', 'edges': {'Jim Jones (rapper)': 1, 'MC Lyte': 1, 'Nas': 1, 'Snoop Dogg': 1, 'Angel Haze': 1, 'Soulja Boy': 1}}, 'Casey Veggies': {'url': '/wiki/Casey_Veggies', 'edges': {'Kirko Bangz': 1, 'Juicy J': 1, 'Dom Kennedy': 3, 'Vince Staples': 1, 'Wiz Khalifa': 1, 'YG (rapper)': 1, 'The Game (rapper)': 1, 'Kendrick Lamar': 1, 'Nipsey Hussle': 1}}, 'Action Bronson': {'url': '/wiki/Action_Bronson', 'edges': {'Mike Will Made It': 1, 'Vince Staples': 1, 'Wiz Khalifa': 1, 'Raekwon': 1, 'Eminem': 2, 'Nas': 2, 'J. Cole': 1, 'Erick Sermon': 1, 'DJ Mustard': 1, 'Kendrick Lamar': 1}}, 'Jim Jones (rapper)': {'url': '/wiki/Jim_Jones_(rapper)', 'edges': {'Lil Wayne': 3, 'Juicy J': 1, '2 Chainz': 1, 'Styles P': 1, 'Dr. Dre': 1, 'Swizz Beatz': 1, 'Juelz Santana': 11, 'Wyclef Jean': 1, 'Young Dro': 1, 'DJ Khaled': 2, 'Meek Mill': 1, 'T.I.': 2, 'DJ Mustard': 1, 'Sean Combs': 2, 'Remy Ma': 1, 'Jadakiss': 2, 'Drumma Boy': 1, 'Raekwon': 1, 'The Game (rapper)': 3, 'Yo Gotti': 1, 'Twista': 1, 'Dej Loaf': 1}}, 'G-Eazy': {'url': '/wiki/G-Eazy', 'edges': {'Lil Wayne': 1, 'YG (rapper)': 1, 'Yo Gotti': 1, '2 Chainz': 1, 'Snoop Dogg': 1}}, 'Styles P': {'url': '/wiki/Styles_P', 'edges': {'Sean Combs': 1, 'Akon':  ...

# %% [markdown]
# ### `save_dict` and `load_dict`
#
# These functions save and load Python dictionaries. This is convenient when you want to save crawl data.

# %%
def save_dict(data, filename):
    import json
    with open(filename, 'w') as f:
        json.dump(data, f)
        
def load_dict(filename):
    import json
    with open(filename, 'r') as f:
        data = json.load(f)
        return data

# %%
save_dict(undirected_graph_dict, "bet_network.json")
print load_dict("bet_network.json")
# Out:
': 1, u'Jon Connor': 1, u'Kevin Gates': 1, u'Ab-Soul': 1, u'Common (rapper)': 1, u'Troy Ave': 1, u'Metro Boomin': 1, u'Isaiah Rashad': 2, u'Lil Uzi Vert': 1, u'Pharrell Williams': 1, u'Lupe Fiasco': 1, u'Twista': 1, u'Schoolboy Q': 1, u'The-Dream': 1}}, u'Scarface (rapper)': {u'url': u'/wiki/Scarface_(rapper)', u'edges': {u'Beanie Sigel': 6, u'Ludacris': 1, u'Akon': 1, u'Nas': 1, u'Freeway (rapper)': 1, u'Ice Cube': 2, u'Tech N9ne': 1, u'Eminem': 1}}, u'Shock G': {u'url': u'/wiki/Shock_G', u'edges': {u'E-40': 1, u'Dr. Dre': 1, u'Money-B': 4}}, u'Ludacris': {u'url': u'/wiki/Ludacris', u'edges': {u'Lil Wayne': 10, u'Common (rapper)': 1, u'Beanie Sigel': 1, u'Bun B': 1, u'DMX (rapper)': 1, u'T.I.': 7, u'Willy Northpole': 2, u'Queen Latifah': 7, u'Wiz Khalifa': 1, u'Nas': 3, u'French Montana': 1, u'Young Jeezy': 7, u'Big K.R.I.T.': 5, u'Timbaland': 11, u'Big Boi': 3, u'Snoop Dogg': 1, u'Lil Jon': 28}}, u'Action Bronson': {u'url': u'/wiki/Action_Bronson', u'edges': {u'Nas': 2, u'Vince Staples': 1, u'Wiz Khalifa': 1, u'Raekwon': 1, u'Eminem': 2, u'Mike Will Made It': 1, u'J. Cole': 1, u'Erick Sermon': 1, u'DJ Mustard': 1, u'Kendrick Lamar': 1}}, u'Jim Jones (rapper)': {u'url': u'/wiki/Jim_Jones_(rapper)', u'edges': {u'Lil Wayne': 3, u'Juicy J': 1, u'2 Chainz': 1, u'Styles P': 1, u'Dr. Dre': 1, u'Swizz Beatz': 1, u'Juelz Santana': 17, u'Wyclef Jean': 1, u'Young Dro': 1, u'DJ Khaled': 2, u'Meek Mill': 1, u'T.I.': 2, u'DJ Mustard': 1, u'Sean Combs': 2, u'Remy Ma': 1, u'Jadakiss': 2, u'Drumma Boy': 1, u'Raekwon': 1, u'The Game (rapper)': 3, u'Yo Gotti': 1, u'Twista': 1, u'Dej Loaf': 1}}, u' ...

# %% [markdown]
# ### Example
#
# In this example, we will use all of the functions above to retrieve and save a social network of characters from the Marvel Cinematic Universe.

# %%
sections = [letter for letter in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ']
sections.append('0-9')
urls = ["https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_" + section for section in sections]

character_links = retrieve_multipage(urls, ".hatnote", True)
write_list(character_links, "marvel_character_links.txt")
print len(character_links), "links retrieved"

mcu_page = PyQuery(url="https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_film_actors")
mcu_links = filter_links(mcu_page)
write_list(mcu_links, "mcu_links.txt")

mcu_characters = intersection(character_links, mcu_links)
write_list(mcu_characters, "mcu_characters.txt")
print len(mcu_characters), "Marvel Cinematic Universe characters"

mcu_crawl_data = crawl("/wiki/Iron_Man", accept=mcu_characters, reject=["/wiki/Marvel_Comics"])
mcu_undirected_graph = undirected_graph(mcu_crawl_data)

save_dict(mcu_undirected_graph, "mcu_network.json")
print load_dict("mcu_network.json")
# Out:
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_A
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_B
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_C
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_D
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_E
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_F
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_G
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_H
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_I
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_J
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_K
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_L
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_M
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_N
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_O
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_P
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Q
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_R
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_S
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_T
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_U
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_V
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_W
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_X
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Y
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_Z
# Retrieving https://en.wikipedia.org/wiki/List_of_Marvel_Comics_characters:_0-9
# 2039 links retrieved
# 112 Marvel Cinematic Universe characters
# 1: Retrieving /wiki/Iron_Man, (0 left in queue)
# 2: Retrieving /wiki/War_Machine, (54 left in queue)
# 3: Retrieving /wiki/Pepper_Potts, (55 left in queue)
# 4: Retrieving /wiki/Captain_America, (56 left in queue)
# 5: Retrieving /wiki/Hawkeye_(comics), (61 left in queue)
# 6: Retrieving /wiki/Ho_Yinsen, (64 left in queue)
# 7: Retrieving /wiki/Thanos, (63 left in queue)
# 8: Retrieving /wiki/Justin_Hammer, (75 left in queue)
# 9: Retrieving /wiki/Howard_Stark, (75 left in queue)
# 10: Retrieving /wiki/Maria_Stark, (74 left in queue)
# 11: Retrieving /wiki/Crimson_Dynamo, (73 left in queue)
# 12: Retrieving /wiki/Happy_Hogan_(comics), (76 left in queue)
# 13: Retrieving /wiki/Iron_Monger, (77 left in queue)
# 14: Retrieving /wiki/Quicksilver_(comics), (76 left in queue)
# 15: Retrieving /wiki/Scarlet_Witch, (76 left in queue)
# 16: Retrieving /wiki/Black_Panther_(comics), (79 left in queue)
# 17: Retrieving /wiki/Doctor_Strange, (83 left in queue)
# 18: Retrieving /wiki/Hank_Pym, (82 left in queue)
# 19: Retrieving /wiki/Ultron, (81 left in queue)
# 20: Retrieving /wiki/Thor_(Marvel_Comics), (80 left in queue)
# 21: Retrieving /wiki/Maria_Hill, (79 left in queue)
# 22: Retrieving /wiki/Friday_(comics), (78 left in queue)
# 23: Retrieving /wiki/Hulk_(comics), (77 left in queue)
# 24: Retrieving /wiki/Whiplash_(comics), (79 left in queue)
# 25: Retrieving /wiki/Wasp_(comics), (78 left in queue)
# 26: Retrieving /wiki/Helmut_Zemo, (77 left in queue)
# 27: Retrieving /wiki/Collector_(comics), (76 left in queue)
# 28: Retrieving /wiki/Grandmaster_(Marvel_Comics), (76 left in queue)
# 29: Retrieving /wiki/Loki_(comics), (75 left in queue)
# 30: Retrieving /wiki/Red_Skull, (74 left in queue)
# 31: Retrieving /wiki/Spider-Man, (73 left in queue)
# 32: Retrieving /wiki/Black_Widow_(Natasha_Romanova), (75 left in queue)
# 33: Retrieving /wiki/Carol_Danvers, (74 left in queue)
# 34: Retrieving /wiki/Vision_(Marvel_Comics), (73 left in queue)
# 35: Retrieving /wiki/Sharon_Carter, (72 left in queue)
# 36: Retrieving /wiki/Nick_Fury, (71 left in queue)
# 37: Retrieving /wiki/Jasper_Sitwell, (70 left in queue)
# 38: Retrieving /wiki/Alexander_Goodwin_Pierce, (69 left in queue)
# 39: Retrieving /wiki/Phil_Coulson, (68 left in queue)
# 40: Retrieving /wiki/Crossbones_(comics), (68 left in queue)
# 41: Retrieving /wiki/Peggy_Carter, (67 left in queue)
# 42: Retrieving /wiki/Gabe_Jones, (66 left in queue)
# 43: Retrieving /wiki/Jane_Foster_(comics), (65 left in queue)
# 44: Retrieving /wiki/Heimdall_(comics), (64 left in queue)
# 45: Retrieving /wiki/Sif_(comics), (63 left in queue)
# 46: Retrieving /wiki/Tyr_(Marvel_Comics), (62 left in queue)
# 47: Retrieving /wiki/Valkyrie_(Marvel_Comics), (61 left in queue)
# 48: Retrieving /wiki/Fandral, (60 left in queue)
# 49: Retrieving /wiki/Hogun, (59 left in queue)
# 50: Retrieving /wiki/Volstagg, (58 left in queue)
# 51: Retrieving /wiki/Ego_the_Living_Planet, (57 left in queue)
# 52: Retrieving /wiki/Executioner_(comics), (56 left in queue)
# 53: Retrieving /wiki/Hela_(comics), (55 left in queue)
# 54: Retrieving /wiki/Kurse, (54 left in queue)
# 55: Retrieving /wiki/Laufey_(comics), (53 left in queue)
# 56: Retrieving /wiki/Malekith_the_Accursed, (52 left in queue)
# 57: Retrieving /wiki/Bucky_Barnes, (51 left in queue)
# 58: Retrieving /wiki/Falcon_(comics), (50 left in queue)
# 59: Retrieving /wiki/Maya_Hansen, (49 left in queue)
# 60: Retrieving /wiki/Aldrich_Killian, (48 left in queue)
# 61: Retrieving /wiki/Klaw_(Marvel_Comics), (47 left in queue)
# 62: Retrieving /wiki/Erik_Selvig, (46 left in queue)
# 63: Retrieving /wiki/Arnim_Zola, (45 left in queue)
# 64: Retrieving /wiki/Baron_Strucker, (44 left in queue)
# 65: Retrieving /wiki/Batroc_the_Leaper, (43 left in queue)
# 66: Retrieving /wiki/Jim_Morita, (42 left in queue)
# 67: Retrieving /wiki/Ant-Man_(Scott_Lang), (41 left in queue)
# 68: Retrieving /wiki/Yellowjacket_(Marvel_Comics), (40 left in queue)
# 69: Retrieving /wiki/Darren_Cross, (39 left in queue)
# 70: Retrieving /wiki/Hope_Pym, (38 left in queue)
# 71: Retrieving /wiki/Drax_the_Destroyer, (37 left in queue)
# 72: Retrieving /wiki/Mantis_(Marvel_Comics), (36 left in queue)
# 73: Retrieving /wiki/Star-Lord, (35 left in queue)
# 74: Retrieving /wiki/Ronan_the_Accuser, (34 left in queue)
# 75: Retrieving /wiki/Gamora, (33 left in queue)
# 76: Retrieving /wiki/Nebula_(comics), (32 left in queue)
# 77: Retrieving /wiki/Yondu, (31 left in queue)
# 78: Retrieving /wiki/Groot, (31 left in queue)
# 79: Retrieving /wiki/Rocket_Raccoon, (30 left in queue)
# 80: Retrieving /wiki/Kismet_(Marvel_Comics), (29 left in queue)
# 81: Retrieving /wiki/Howard_the_Duck, (28 left in queue)
# 82: Retrieving /wiki/Supernova_(Marvel_Comics), (28 left in queue)
# 83: Retrieving /wiki/Rhomann_Dey, (27 left in queue)
# 84: Retrieving /wiki/Trevor_Slattery, (26 left in queue)
# 85: Retrieving /wiki/Tinkerer, (25 left in queue)
# 86: Retrieving /wiki/Doc_Samson, (24 left in queue)
# 87: Retrieving /wiki/Abomination_(comics), (23 left in queue)
# 88: Retrieving /wiki/Thunderbolt_Ross, (22 left in queue)
# 89: Retrieving /wiki/Coldblood, (21 left in queue)
# 90: Retrieving /wiki/Vulture_(Marvel_Comics), (20 left in queue)
